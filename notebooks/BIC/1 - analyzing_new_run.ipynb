# %% [markdown]
# In this notebook we analyze the BIC from the very long run, mostly seeing where the minimum is and relative factors etc

# %%
from deepymod.analysis import load_tensorboard

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = load_tensorboard('runs/BIC_initial_kdv/')

# %%
plt.plot(df.BIC)
plt.axvline(df.BIC.idxmin(), linestyle='--', color='k')

# %% [markdown]
# We can also plot the $\delta$ BIC compared to the minimum:

# %%
plt.semilogy(df.BIC - df.BIC.min())

# %%
df.iloc[df.BIC.idxmin()]
# Out:
# BIC                -14833.386719
# beta                  293.122101
# its                    10.000000
# loss                -6084.062500
# mse                     0.003390
# p_mse                1424.505127
# p_reg                4659.557617
# reg                     0.000117
# tau                   295.004425
# alpha_11           100000.000000
# alpha_0            100000.000000
# alpha_8            100000.000000
# alpha_4            100000.000000
# alpha_5                 0.027780
# alpha_6             72462.070312
# alpha_7             99228.179688
# alpha_2             86106.679688
# alpha_10           100000.000000
# alpha_1             36182.886719
# alpha_9             25488.431641
# alpha_3                 1.016569
# coeffs_11               0.000000
# coeffs_0                0.000000
# coeffs_8                0.000000
# coeffs_4                0.000000
# coeffs_5               -5.996779
# coeffs_6                0.000000
# coeffs_7                0.000000
# ...
