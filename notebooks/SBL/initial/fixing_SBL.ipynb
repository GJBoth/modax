# %%
# %% Imports
from jax.api import value_and_grad
from jax.config import config

config.update("jax_debug_nans", True)

from jax import numpy as jnp, random
import jax
from modax.data.burgers import burgers
from modax.data.kdv import doublesoliton
from modax.models import Deepmod
from modax.training.utils import create_update
from flax import optim

from modax.training.losses.SBL import loss_fn_SBL
from modax.training import train_max_iter
from sklearn.linear_model import ARDRegression
from modax.linear_model.SBL import SBL

from flax.core import unfreeze
import flax
# %load_ext autoreload
# %autoreload 2

# %%
# %% Making data
key = random.PRNGKey(42)

x = jnp.linspace(-3, 4, 50)
t = jnp.linspace(0.5, 5.0, 20)
t_grid, x_grid = jnp.meshgrid(t, x, indexing="ij")
u = burgers(x_grid, t_grid, 0.1, 1.0)

X = jnp.concatenate([t_grid.reshape(-1, 1), x_grid.reshape(-1, 1)], axis=1)
y = u.reshape(-1, 1)
y += 0.10 * jnp.std(y) * random.normal(key, y.shape)

# %%
# %% Building model and params
model = Deepmod([30, 30, 30, 1])
variables = model.init(key, X)

optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state
update_fn = create_update(loss_fn_SBL, (model, X, y, False))

# %%
grad_fn = jax.value_and_grad(loss_fn_SBL, has_aux=True)
(loss, (updated_state, metrics, output)), grad = grad_fn(
    optimizer.target, state, model, X, y
)

# %%
print(loss)

# %%
def check_grads_for_nan(grads):
    flattened_grads = flax.traverse_util.flatten_dict(unfreeze(grads))
    flattened_grads = jnp.concatenate([data.flatten() for key, data in flattened_grads.items()])
    
    return jnp.any(jnp.isnan(flattened_grads))

# %%
check_grads_for_nan(grad)

# %%
metrics

# %% [markdown]
# Okay so it reached the maximum number of iterations, maybe we should fix that later; is that a problem though?
#
# No it isn't cause the differentiation is independent of the value; could be 10 or 100 as well.
# We can probably fix this later using the fast marginalization property. Let's see how many iteration sklearn needs:

# %%
model_state, loss_state = state
variables = {"params": params, **model_state}
(prediction, dt, theta, coeffs), updated_model_state = model.apply(
    variables, X, mutable=list(model_state.keys())
)

theta_normed = theta / jnp.linalg.norm(theta, axis=0)
n_samples, n_features = theta.shape
tau = 1 / jnp.mean((y - prediction) ** 2)
hyper_prior = (n_samples / 2, n_samples / 2 * 1 / tau)

reg = ARDRegression(
    fit_intercept=False,
    compute_score=True,
    tol=1e-3 * tau,
    alpha_1=hyper_prior[0],
    alpha_2=hyper_prior[1],
    threshold_lambda=1e6,
)
reg.fit(theta_normed, dt.squeeze())

reg.scores_

# %% [markdown]
# Much less but that's because of their convergence criterium; let's check the difference in alpha and beta

# %%
print(jnp.stack([reg.lambda_, metrics['alpha']], axis=1))

# %%
jnp.abs(reg.lambda_ - metrics['alpha']) / reg.lambda_

# %% [markdown]
# Which is fairly small save for one or two terms. So everythnig seems alright here; let's run it for a while:

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)

# %% [markdown]
# Okay so we're getting Nans, seems to be in the custom backprop. Let's up the number of iterations:

# %%
optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)

# %% [markdown]
# So it's not an issue with that, and also not with the jit. What about setting the hyperprior standard, would that fix it?

# %%
# %% Building model and params
model = Deepmod([30, 30, 30, 1])
variables = model.init(key, X)

optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state
update_fn = create_update(loss_fn_SBL, (model, X, y, False))

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)

# %% [markdown]
# So that ran without error, good. That would imply it's an issue with the hyperprior. Now what if we run kdv?

# %%
key = random.PRNGKey(42)
x = jnp.linspace(-10, 10, 100)
t = jnp.linspace(0.1, 1.0, 10)
t_grid, x_grid = jnp.meshgrid(t, x, indexing="ij")
u = doublesoliton(x_grid, t_grid, c=[5.0, 2.0], x0=[0.0, -5.0])

X = jnp.concatenate([t_grid.reshape(-1, 1), x_grid.reshape(-1, 1)], axis=1)
y = u.reshape(-1, 1)
y += 0.10 * jnp.std(y) * random.normal(key, y.shape)

# %%
# %% Building model and params
model = Deepmod([30, 30, 30, 1])
variables = model.init(key, X)

optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state
update_fn = create_update(loss_fn_SBL, (model, X, y, False))

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)

# %% [markdown]
# Okay so that gets stuck; weird. Maybe remove the max iterations?

# %%
# %% Building model and params
model = Deepmod([30, 30, 30, 1])
variables = model.init(key, X)

optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state
update_fn = create_update(loss_fn_SBL, (model, X, y, False))

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)

# %% [markdown]
# Okay so it's not only that... Maybe let's use a really back ficed point solver for the backwards pass?

# %%
# %% Building model and params
model = Deepmod([30, 30, 30, 1])
variables = model.init(key, X)

optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state
update_fn = create_update(loss_fn_SBL, (model, X, y, False))

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)

# %% [markdown]
# Same issue... What if we used the simple one in the forward pass as well?

# %%
# %% Building model and params
model = Deepmod([30, 30, 30, 1])
variables = model.init(key, X)

optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state
update_fn = create_update(loss_fn_SBL, (model, X, y, False))

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)

# %% [markdown]
# Okay so it gets stuck; does it get stuck on the forward on backward pass? Let's limit the forward pass.

# %%
# %% Building model and params
model = Deepmod([30, 30, 30, 1])
variables = model.init(key, X)

optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state
update_fn = create_update(loss_fn_SBL, (model, X, y, False))

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)

# %%
# %% Building model and params
model = Deepmod([30, 30, 30, 1])
variables = model.init(key, X)

optimizer = optim.Adam(learning_rate=2e-3, beta1=0.99, beta2=0.99)
state, params = variables.pop("params")
optimizer = optimizer.create(params)

state = (state, {"prior_init": None})  # adding prior to state
update_fn = create_update(loss_fn_SBL, (model, X, y, False))

# %%
optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)
# Out:
# Loss step 0: -1080.5452880859375
# Loss step 1: -1500.6864013671875
# Loss step 2: -1901.683837890625
# Loss step 3: -1863.78271484375
# Loss step 4: -1811.1790771484375
# Loss step 5: -2057.734130859375
# Loss step 6: -2330.02587890625
# Loss step 7: -2495.3330078125
# Loss step 8: -2549.15234375
# Loss step 9: -2404.401611328125
# Loss step 10: -2514.052490234375
# Loss step 11: -2837.67724609375
# Loss step 12: -2988.36962890625
# Loss step 13: -3150.870849609375
# Loss step 14: -3011.189697265625
# Loss step 15: -3049.209228515625
# Loss step 16: -3191.8525390625
# Loss step 17: -3220.287109375
# Loss step 18: -3403.50341796875
# Loss step 19: -3307.265625
# Loss step 20: -3272.236572265625
# Loss step 21: -3322.76611328125
# Loss step 22: -3396.041015625
# Loss step 23: -3734.49072265625
# Loss step 24: -3723.11083984375
# Loss step 25: -3538.55810546875
# Loss step 26: -3426.380615234375
# Loss step 27: -3476.582763671875
# Loss step 28: -3828.815185546875
# Loss step 29: -4077.4521484375
# Loss step 30: -3904.801513671875
# Loss step 31: -3743.05126953125
# Loss step 32: -3861.195068359375
# Loss step 33: -4141.5087890625
# Loss step 34: -4116.888671875
# Loss step 35: -3907.03076171875
# Loss step 36: -3816.189697265625
# Loss step 37: -3935.928955078125
# Loss step 38: -4158.388671875
# Loss step 39: -4370.244140625
# Loss step 40: -4132.27392578125
# Loss step 41: -3948.6640625
# Loss step 42: -3921.56640625
# Loss step 43: -4090.504150390625
# Loss step 44: -4550.412109375
# Loss step 45: -4485.8427734375
# Loss step 46: -4212.78759765625
# Loss step 47: -4182.58251953125
# Loss step 48: -4391.5244140625
# Loss step 49: -4624.259765625
# Loss step 50: -4412.4677734375
# Loss step 51: -4194.21826171875
# Loss step 52: -4158.30029296875
# Loss step 53: -4303.4501953125
# Loss step 54: -4595.583984375
# Loss step 55: -4648.53271484375
# Loss step 56: -4373.1484375
# Loss step 57: -4261.4501953125
# Loss step 58: -4403.92724609375
# Loss step 59: -4797.58837890625
# Loss step 60: -4835.0859375
# Loss step 61: -4524.6044921875
# Loss step 62: -4362.15380859375
# Loss step 63: -4435.9755859375
# Loss step 64: -4657.74365234375
# Loss step 65: -4782.5791015625
# Loss step 66: -4611.8447265625
# Loss step 67: -4524.4541015625
# Loss step 68: -4668.21044921875
# Loss step 69: -5060.9443359375
# Loss step 70: -5089.4111328125
# Loss step 71: -4622.10400390625
# Loss step 72: -4674.47509765625
# Loss step 73: -4505.28759765625
# Loss step 74: -4385.20263671875
# Loss step 75: -3863.06787109375
# Loss step 76: -3531.2197265625
# Loss step 77: -3322.376708984375
# Loss step 78: -3184.7529296875
# Loss step 79: -3092.95849609375
# Loss step 80: -3033.78369140625
# Loss step 277: -4365.21533203125
# Loss step 278: -4502.96875
# Loss step 279: -4713.05078125
# Loss step 280: -4951.61474609375
# Loss step 281: -4931.61474609375
# Loss step 282: -4741.1953125
# Loss step 283: -4542.677734375
# Loss step 284: -4392.68798828125
# Loss step 285: -4298.8134765625
# Loss step 286: -4255.8427734375
# Loss step 287: -4259.2919921875
# Loss step 288: -4308.31689453125
# Loss step 289: -4405.63232421875
# Loss step 290: -4553.869140625
# Loss step 291: -4734.4599609375
# Loss step 292: -4852.5693359375
# Loss step 293: -4816.7958984375
# Loss step 294: -4686.03759765625
# Loss step 295: -4531.44580078125
# Loss step 296: -4392.880859375
# Loss step 297: -4285.2822265625
# Loss step 298: -4210.09326171875
# Loss step 299: -4165.2177734375
# Loss step 300: -4149.02294921875
# Loss step 301: -4161.65625
# Loss step 302: -4205.84228515625
# Loss step 303: -4288.12109375
# Loss step 304: -4421.54150390625
# Loss step 305: -4630.97314453125
# Loss step 306: -4952.7412109375
# Loss step 307: -5300.880859375
# Loss step 308: -5218.71826171875
# Loss step 309: -4895.7685546875
# Loss step 310: -4709.7314453125
# Loss step 311: -4619.9892578125
# Loss step 312: -4597.50390625
# Loss step 313: -4642.443359375
# Loss step 314: -4785.34521484375
# Loss step 315: -5099.9013671875
# Loss step 316: -5519.03857421875
# Loss step 317: -5450.15869140625
# Invalid value encountered in the output of a jit function. Calling the de-optimized version.
# ---------------------------------------------------------------------------
# FilteredStackTrace                        Traceback (most recent call last)
# <ipython-input-11-21d40bdba709> in <module>
# ----> 1 optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)
#
# ~/Documents/modax/src/modax/training/training.py in train_max_iter(update_fn, optimizer, state, max_epochs)
#      13     for epoch in jnp.arange(max_epochs):
# ---> 14         (optimizer, state), metrics, output = update_fn(optimizer, state)
#      15
#
# ~/Documents/modax/src/modax/training/utils.py in step(opt, state, loss_fn, loss_fn_args)
#       7         grad_fn = value_and_grad(loss_fn, argnums=0, has_aux=True)
# ----> 8         (loss, (updated_state, metrics, output)), grad = grad_fn(
#       9             opt.target, state, *loss_fn_args
#
# FilteredStackTrace: jax.linear_util.StoreException: Store empty
#
# The stack trace above excludes JAX-internal frames.
# The following is the original exception that occurred, unmodified.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# StoreException                            Traceback (most recent call last)
# <ipython-input-11-21d40bdba709> in <module>
# ----> 1 optimizer, state = train_max_iter(update_fn, optimizer, state, 10000)
#
# ~/Documents/modax/src/modax/training/training.py in train_max_iter(update_fn, optimizer, state, max_epochs)
#      12     logger = Logger()
#      13     for epoch in jnp.arange(max_epochs):
# ---> 14         (optimizer, state), metrics, output = update_fn(optimizer, state)
#      15
#      16         if epoch % 1 == 0:
#
# ~/anaconda3/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     355     # TODO(jblespiau): Move this to C++.
#     356     if FLAGS.jax_debug_nans and not _jit_is_disabled():
# --> 357       device_arrays = cpp_jitted_f(*args, **kwargs)
#     358       try:
#     359         xla.check_nans(xla.xla_call_p, [
#
# ~/anaconda3/lib/python3.8/site-packages/jax/api.py in cache_miss(*args, **kwargs)
#     276       _check_arg(arg)
#     277     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 278     out_flat = xla.xla_call(
#     279         flat_fun,
#     280         *args_flat,
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1227
#    1228   def bind(self, fun, *args, **params):
# -> 1229     return call_bind(self, fun, *args, **params)
#    1230
#    1231   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1218   tracers = map(top_trace.full_raise, args)
#    1219   with maybe_new_sublevel(top_trace):
# -> 1220     outs = primitive.process(top_trace, fun, tracers, params)
#    1221   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1222
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1230
#    1231   def process(self, trace, fun, tracers, params):
# -> 1232     return trace.process_call(self, fun, tracers, params)
#    1233
#    1234   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     596
#     597   def process_call(self, primitive, f, tracers, params):
# --> 598     return primitive.impl(f, *tracers, **params)
#     599   process_map = process_call
#     600
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     584     # be empty.
#     585     for store in fun.stores: store and store.reset()
# --> 586     return fun.call_wrapped(*args)  # probably won't return
#     587
#     588 def flatten_shape(s: XlaShape) -> Sequence[Tuple[Sequence[int], XlaShape]]:
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     158
#     159     try:
# --> 160       ans = self.f(*args, **dict(self.params, **kwargs))
#     161     except:
#     162       # Some transformations yield from inside context managers, so we have to
#
# ~/Documents/modax/src/modax/training/utils.py in step(opt, state, loss_fn, loss_fn_args)
#       6     def step(opt, state, loss_fn, loss_fn_args):
#       7         grad_fn = value_and_grad(loss_fn, argnums=0, has_aux=True)
# ----> 8         (loss, (updated_state, metrics, output)), grad = grad_fn(
#       9             opt.target, state, *loss_fn_args
#      10         )
#
# ~/anaconda3/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/api.py in value_and_grad_f(*args, **kwargs)
#     773     dtype = dtypes.result_type(ans)
#     774     tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 775     g = vjp_py(np.ones((), dtype=dtype))
#     776     g = g[0] if isinstance(argnums, int) else g
#     777     if not has_aux:
#
# ~/anaconda3/lib/python3.8/site-packages/jax/api.py in _vjp_pullback_wrapper(cotangent_dtypes, io_tree, fun, py_args)
#    1790              "with dtype {}.")
#    1791       raise TypeError(msg.format(ct_dtype, expected_tangent_dtype, _dtype(arg)))
# -> 1792   ans = fun(*args)
#    1793   return tree_unflatten(out_tree, ans)
#    1794
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/ad.py in unbound_vjp(pvals, jaxpr, consts, *cts)
#     119     cts = tuple(map(ignore_consts, cts, pvals))
#     120     dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 121     arg_cts = backward_pass(jaxpr, consts, dummy_args, cts)
#     122     return map(instantiate_zeros, arg_cts)
#     123
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/ad.py in backward_pass(jaxpr, consts, primals_in, cotangents_in)
#     225             params, call_jaxpr, invals, cts_in, cts_in_avals)
#     226       else:
# --> 227         cts_out = get_primitive_transpose(eqn.primitive)(cts_in, *invals,
#     228                                                          **eqn.params)
#     229     cts_out = [Zero(v.aval) for v in eqn.invars] if cts_out is Zero else cts_out
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/ad.py in _custom_lin_transpose(cts_out, num_res, bwd, avals_out, *invals)
#     685   res, _ = split_list(invals, [num_res])
#     686   cts_out = map(instantiate_zeros_aval, avals_out, cts_out)
# --> 687   cts_in = bwd.call_wrapped(*res, *cts_out)
#     688   return [None] * num_res + list(cts_in)
#     689 primitive_transposes[custom_lin_p] = _custom_lin_transpose
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     158
#     159     try:
# --> 160       ans = self.f(*args, **dict(self.params, **kwargs))
#     161     except:
#     162       # Some transformations yield from inside context managers, so we have to
#
# ~/anaconda3/lib/python3.8/site-packages/jax/_src/traceback_util.py in reraise_with_filtered_traceback(*args, **kwargs)
#     137   def reraise_with_filtered_traceback(*args, **kwargs):
#     138     try:
# --> 139       return fun(*args, **kwargs)
#     140     except Exception as e:
#     141       if not is_under_reraiser(e):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/api.py in f_jitted(*args, **kwargs)
#     355     # TODO(jblespiau): Move this to C++.
#     356     if FLAGS.jax_debug_nans and not _jit_is_disabled():
# --> 357       device_arrays = cpp_jitted_f(*args, **kwargs)
#     358       try:
#     359         xla.check_nans(xla.xla_call_p, [
#
# ~/anaconda3/lib/python3.8/site-packages/jax/api.py in cache_miss(*args, **kwargs)
#     276       _check_arg(arg)
#     277     flat_fun, out_tree = flatten_fun(f, in_tree)
# --> 278     out_flat = xla.xla_call(
#     279         flat_fun,
#     280         *args_flat,
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in bind(self, fun, *args, **params)
#    1227
#    1228   def bind(self, fun, *args, **params):
# -> 1229     return call_bind(self, fun, *args, **params)
#    1230
#    1231   def process(self, trace, fun, tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in call_bind(primitive, fun, *args, **params)
#    1218   tracers = map(top_trace.full_raise, args)
#    1219   with maybe_new_sublevel(top_trace):
# -> 1220     outs = primitive.process(top_trace, fun, tracers, params)
#    1221   return map(full_lower, apply_todos(env_trace_todo(), outs))
#    1222
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in process(self, trace, fun, tracers, params)
#    1230
#    1231   def process(self, trace, fun, tracers, params):
# -> 1232     return trace.process_call(self, fun, tracers, params)
#    1233
#    1234   def post_process(self, trace, out_tracers, params):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/core.py in process_call(self, primitive, f, tracers, params)
#     596
#     597   def process_call(self, primitive, f, tracers, params):
# --> 598     return primitive.impl(f, *tracers, **params)
#     599   process_map = process_call
#     600
#
# ~/anaconda3/lib/python3.8/site-packages/jax/interpreters/xla.py in _xla_call_impl(fun, device, backend, name, donated_invars, *args)
#     567
#     568 def _xla_call_impl(fun: lu.WrappedFun, *args, device, backend, name, donated_invars):
# --> 569   compiled_fun = _xla_callable(fun, device, backend, name, donated_invars,
#     570                                *unsafe_map(arg_spec, args))
#     571   try:
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in memoized_fun(fun, *args)
#     247     if result is not None:
#     248       ans, stores = result
# --> 249       fun.populate_stores(stores)
#     250     else:
#     251       ans = call(fun, *args)
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in populate_stores(self, stores)
#     142     for self_store, other_store in zip(self.stores, stores):
#     143       if self_store is not None:
# --> 144         self_store.store(other_store.val)
#     145
#     146   def call_wrapped(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/jax/linear_util.py in val(self)
#      98   def val(self):
#      99     if not self:
# --> 100       raise StoreException("Store empty")
#     101     return self._val
#     102
#
# StoreException: Store empty
